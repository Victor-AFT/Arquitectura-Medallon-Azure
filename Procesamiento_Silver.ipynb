# %%
from pyspark.sql.functions import col, unix_timestamp, struct, to_json, collect_list



# CONFIG STORAGE
spark.conf.set(
"fs.azure.account.key.XXXX.blob.core.windows.net","XXXX")

base = "wasbs://silver@XXXX.blob.core.windows.net/"


# LOAD TABLES
aircraft = spark.read.csv(base+"aircraft.csv", header=True, inferSchema=True)
airline = spark.read.csv(base+"airline.csv", header=True, inferSchema=True)
flights = spark.read.csv(base+"flights.csv", header=True, inferSchema=True)
flight_numbers = spark.read.csv(base+"flight_info.csv", header=True, inferSchema=True)
departure = spark.read.csv(base+"departure.csv", header=True, inferSchema=True)
arrival = spark.read.csv(base+"arrival.csv", header=True, inferSchema=True)

#CONTENIDO DE FICHEROS

print("CONTENIDO FICHERO AIRCRAFT")
aircraft.display()
print("CONTENIDO FICHERO AIRLINE")
airline.display()
print("CONTENIDO FICHERO FLIGHTS")
flights.display()
print("CONTENIDO FICHERO FLIGHT INFO")
flight_numbers.display()
print("CONTENIDO FICHERO DEPARTURE")
departure.display()
print("CONTENIDO FICHERO ARRIVAL")
arrival.display()
# Out:
# CONTENIDO FICHERO AIRCRAFT
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#CREACION DE JSON CON LOS FICHEROS UNIFICADO
json_unificado = (
    flights.alias("f")
    .join(airline.alias("al"), "flight_id", "left")
    .join(aircraft.alias("ac"), "flight_id", "left")
    .join(departure.alias("d"), "flight_id", "left")
    .join(arrival.alias("a"), "flight_id", "left")
    .join(flight_numbers.alias("fn"), "flight_id", "left")
    .select(
        col("f.flight_id"),
        col("f.flight_date"),
        col("f.flight_status"),
        col("fn.number").alias("flight_number"),
        col("fn.iata").alias("flight_number_iata"),
        col("fn.icao").alias("flight_number_icao"),
        col("al.name").alias("airline_name"),
        col("al.iata").alias("airline_iata"),
        col("al.icao").alias("airline_icao"),
        col("ac.registration").alias("aircraft_registration"),
        col("ac.iata").alias("aircraft_iata"),
        col("ac.icao").alias("aircraft_icao"),
        col("ac.icao24").alias("aircraft_icao24"),
        col("d.airport").alias("departure_airport"),
        col("d.scheduled").alias("departure_scheduled"),
        col("d.actual").alias("departure_actual"),
        col("d.delay").alias("departure_delay"),
        col("d.gate").alias("departure_gate"),
        col("d.terminal").alias("departure_terminal"),
        col("d.estimated_runway").alias("departure_estimated_runway"),
        col("a.airport").alias("arrival_airport"),
        col("a.scheduled").alias("arrival_scheduled"),
        col("a.actual").alias("arrival_actual"),
        col("a.delay").alias("arrival_delay"),
        col("a.gate").alias("arrival_gate"),
        col("a.terminal").alias("arrival_terminal"),
        col("a.estimated_runway").alias("arrival_estimated_runway")
    )
)

# %%
display(json_unificado)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
base = "wasbs://gold@XXXX.blob.core.windows.net/"
temp_output = base + "_tmp_json/"
final_file = base + "vuelos.json"

# WRITE TEMP JSON (1 FILE)

(
    json_unificado
    .coalesce(1)
    .write
    .mode("overwrite")
    .json(temp_output)
)


# RENAME PART → vuelos.json

files = dbutils.fs.ls(temp_output)
json_file = [f.path for f in files if f.path.endswith(".json")][0]

dbutils.fs.mv(json_file, final_file, True)
dbutils.fs.rm(temp_output, True)

print("Archivo final creado:", final_file)

# %%
# LEER EL FICHERO JSON CREADO ANTERIORMENTE
vuelos_path = "wasbs://gold@XXXX.blob.core.windows.net/vuelos.json"
vuelos_df = spark.read.json(vuelos_path)

# Crear la tabla 'vuelos' en la base de datos
password_bbdd='XXXXXX'
jdbc_url = f"jdbc:sqlserver://XXX.database.windows.net:1433;database=XXXX;user=user1@sqlmi-vftpc5-sbx-euw1;password={password_bbdd};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"

# Crear la tabla solo si no existe, y sin escribir datos
if not spark._jsparkSession.catalog().tableExists("vuelos"):
    vuelos_df.limit(0).write.jdbc(
        url=jdbc_url,
        table="vuelos",
        mode="overwrite"
    )
